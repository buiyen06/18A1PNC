# %%
import pandas as pd
import numpy as np

# %%
ser = pd.Series(np.random.normal(10, 5, 25))

# %%
ser.min()
# Out:
# np.float64(2.0607580027163213)

# %%
np.percentile(ser,25)
# Out:
# np.float64(6.5316730379212)

# %%
ser.mean()
# Out:
# np.float64(10.001365724120353)

# %%
np.percentile(ser,75)
# Out:
# np.float64(13.953646353693419)

# %%
ser.max()
# Out:
# np.float64(17.14700366581172)
