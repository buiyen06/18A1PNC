# %%
ser = pd.Series(np.random.randint(1, 10, 35))
#1. Ý nghĩa mã lệnh:
# np.random.randint(1, 10, 35): Tạo một mảng numpy chứa 35 số nguyên ngẫu nhiên từ 1 đến 9.
# pd.Series(...): Tạo một đối tượng Series từ mảng số nguyên vừa tạo.
# Như vậy, đoạn mã này tạo ra một Series (ser) có 35 phần tử, mỗi phần tử là một số nguyên ngẫu nhiên từ 1 đến 9.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ser = pd.Series(np.random.randint(1, 10, 35))
#       2 #1. Ý nghĩa mã lệnh:
#       3 # np.random.randint(1, 10, 35): Tạo một mảng numpy chứa 35 số nguyên ngẫu nhiên từ 1 đến 9.
#       4 # pd.Series(...): Tạo một đối tượng Series từ mảng số nguyên vừa tạo.
#       5 # Như vậy, đoạn mã này tạo ra một Series (ser) có 35 phần tử, mỗi phần tử là một số nguyên ngẫu nhiên từ 1 đến 9.
#
# NameError: name 'pd' is not defined

# %% [markdown]
# 2.Định hình lại ser thành một DataFrame có 7 hàng và 5 cột

# %%
import pandas as pd
import numpy as np

ser = pd.Series(np.random.randint(1, 10, 35))

# %%
df = pd.DataFrame(np.array(ser).reshape(7, 5), columns=['Col1', 'Col2', 'Col3', 'Col4', 'Col5'])
print(df)
# Out:
#    Col1  Col2  Col3  Col4  Col5
# 0     5     9     6     2     6
# 1     7     8     3     5     6
# 2     3     9     6     2     7
# 3     5     2     6     7     3
# 4     3     6     1     2     7
# 5     7     9     2     4     8
# 6     9     3     4     4     3
